# %%
import pandas as pd
import numpy as np
import pickle
import operator
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split as tts
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder as LE
from sklearn.metrics.pairwise import cosine_similarity
import random
import nltk
from nltk.stem.lancaster import LancasterStemmer

# %%
data=pd.read_csv("F:\\Download 2\\data.csv", sep="?")

# %%
data
# Out:
#                                              Question  \
# 0                   What is the timeline for applying
# 1                How will my application be evaluated
# 2   In which part of the application may I enter a...
# 3   How do I add new information if I have already...
# 4   Does the reputation/history of my undergraduat...
# 5   When I print the application in PDF format par...
# 6   What is the desired length of work experience ...
# 7                    What constitutes work experience
# 8   Are there specific types of work experience th...
# 9                Who should recommendations come from
# 10               What is the process for recommenders
# 11  Is the recommendation deadline the same as the...
# 12  When should I expect an invitation for an inte...
# 13              What should I expect for my interview
# 14                             How can I best prepare
# 15  How can I learn more about the Post Interview ...
# 16  Who should I contact if I have a question rega...
# 17    When and how can I expect to hear back from HBS
# 18  Will HBS provide feedback for applicants who h...
# 19                 How long can I defer my acceptance
# 20                        What is the application fee
# 21          Am I eligible to apply to the 2+2 Program
# 22               What Round should I apply in for 2+2
# 23  I am in the process of getting a master’s degr...
# 24  Are international students eligible to apply t...
# 25  Is an interview required for admission to the ...
# 26    How many seats are available in the 2+2 program
# 27  Which standardized tests does the 2+2 Program ...
# 28      When is the latest I can take the GMAT or GRE
# 29  My undergraduate concentration is in a busines...
# ..                                                ...
# 45  What is the range of GMAT/GRE scores for accep...
# 46          Can I list only my best GMAT or GRE score
# 47  Do I need to complete the AWA section of the G...
# 48  Do I need to complete the Integrated Reasoning...
# 49   Who is required to take an English Language test
# 50  What if I have lived and worked in an English ...
# 51  What if part of my bachelor's degree was part ...
# 52  What if my undergraduate degree was not in Eng...
# 53  What is the latest date English test scores wi...
# 54                         What is the HBS TOEFL code
# 55  Is there a minimum TOEFL/IELTS/PTE test score ...
# 56                     How can I submit my transcript
# 57        Is there a minimum GPA requirement to apply
# 58       What is the average GPA of accepted students
# 59  Do you accept transfer credits from another co...
# 60  Financial Aid: What is the estimated cost for ...
# 61  Financial Aid: What are some options for finan...
# 62  Case Method: What makes the HBS case method su...
# 63         Sections: How is the curriculum structured
# 64  Academic Environment: Is it possible to cross ...
# 65    Program Offerings: Does HBS offer an online MBA
# 66  Program Offerings: Does HBS offer a part-time ...
# 67  What are the extracurricular activities available
# 68        What percentage of students lives on campus
# 69                 What are my transportation options
# 70  What social opportunities do Harvard Square an...
# 71                How can I sign up for a campus tour
# 72  How can I sign up for a classroom visit and is...
# 73         What events are held for accepted students
# 74  As a student, will I have the opportunity to n...
#
#                                                Answer
# 0                         View application deadlines.
# 1   Each application received is reviewed in depth...
# 2   Please enter important information that you wa...
# 3   Once the application has been submitted the Ad...
# 4   Our goal is to admit a class that offers a var...
# 5   The Admissions Office receives the entire appl...
# 6   The HBS MBA Program is designed for students w...
# 7   Work experience includes opportunities in whic...
# 8   Rather than focus on specific categories of wo...
# 9   The Admissions Board suggests that one recomme...
# 10  Candidates enter recommenders' names and email...
# 11  Applicants should submit their applications as...
# 12  Interview invitations are extended on a rollin...
# 13  Your interview will last approximately 30 minu...
# 14  The purpose of the interview is to better unde...
# 15  Details for the Post Interview Reflection will...
# 16  Any questions you have should be submitted to ...
# 17  Notification dates are set according to each r...
# 18  Due to the large number of applications we rec...
# 19  Candidates should submit applications only for...
# 20  The application fee for the 2+2 Program applic...
# 21  To be considered for admission to the 2+2 Prog...
# 22    You can only apply in the designated 2+2 Round.
# 23  Yes. Candidates in the process of completing a...
# 24  Yes. Domestic and international students alike...
# 25  Yes. Interviews are conducted by invitation on...
# 26  We expect the 2+2 cohort size to be in the 100...
# 27  The 2+2 Program accepts either the GMAT or the...
# 28  You must take the GMAT or GRE by April 10, 201...
# 29  When the 2+2 Program was originally created it...
# ..                                                ...
# 45  The Admissions Board hopes that all applicants...
# 46  Yes.  We consider only the score from a single...
# 47  Yes. You do not need to have the results of th...
# 48  Yes. Anyone who takes the GMAT on or after Jun...
# 49  If you only have a degree (or degrees) from a ...
# 50  Again, if you only have a degree (or degrees) ...
# 51  In this case, you are still required to take a...
# 52  Though it is not required as part of your init...
# 53  TOEFL, IELTS, and Pearson Test of English (PTE...
# 54  Please note that the HBS code for the TOEFL is...
# 55  HBS does not have a minimum test score to appl...
# 56  Transcripts must be scanned and uploaded to th...
# 57  No. Although our students often have competiti...
# 58  Because we recognize that different schools us...
# 59  No, we do no accept transfer credits of any ki...
# 60  While living expenses vary from student to stu...
# 61  HBS is committed to making the MBA Program acc...
# 62  The case method prepares students for the chal...
# 63  Students spend their first two terms completin...
# 64  Yes. HBS students are able to cross register a...
# 65  Harvard Business School does not offer an onli...
# 66  HBS has one MBA program, and it is offered onl...
# 67  Harvard Business School is home to over 70 ind...
# 68  Over 80% of HBS students live in HBS dorms or ...
# 69  The HBS campus is accessible via either car or...
# 70  Harvard Square and the neighboring Cambridge a...
# 71  There is no need to sign up for a campus tour....
# 72  To schedule a class visit please refer to the ...
# 73  We hold Admitted Student Welcome events on cam...
# 74  Absolutely. HBS has many networking events and...
#
# [75 rows x 2 columns]

# %%
#dfi = pd.DataFrame(columns=['i'])
#dfi = dfi.fillna(0)

data['Class'] = data['Answer']

# %%
#data.loc[data['id'] > 2000, "first_name"] = "John"
#for i in len(qa);
#qa.replace(, np.nan)
##qa.i.iloc[[1, 3, 15]] = 88
##df.ix[0, 'COL_NAME'] = x
#qa2 = qa.loc[qa.iloc[0], "a"] = "Application General"
#qa2=qa.loc[qa.iloc[0:5], "i"] = "Application General"

data.iloc[0:6, data.columns.get_loc('Class')] = 'Application General'
data.iloc[6:9, data.columns.get_loc('Class')] = 'Work Experience'
data.iloc[9:12, data.columns.get_loc('Class')] = 'Recommendations'
data.iloc[12:15, data.columns.get_loc('Class')] = 'Interview'
data.iloc[15, data.columns.get_loc('Class')] = 'Post Interview Reflection'
data.iloc[16:20, data.columns.get_loc('Class')] = 'Application Follow-up'
data.iloc[20:41, data.columns.get_loc('Class')] = '2+2 Program'
data.iloc[41:49, data.columns.get_loc('Class')] = 'GMAT and GRE Tests'
data.iloc[49:56, data.columns.get_loc('Class')] = 'English Language Tests (TOEFL, IELTS, PTE)'
data.iloc[56:60, data.columns.get_loc('Class')] = 'Transcripts'
data.iloc[60:62, data.columns.get_loc('Class')] = 'Financing your MBA'
data.iloc[62:67, data.columns.get_loc('Class')] = 'HBS Learning Model'
data.iloc[67:71, data.columns.get_loc('Class')] = 'Student Life'
data.iloc[71:75, data.columns.get_loc('Class')] = 'Events and Networking Opportunities'

# %%
#data.iloc[71]
data
# Out:
#                                              Question  \
# 0                   What is the timeline for applying
# 1                How will my application be evaluated
# 2   In which part of the application may I enter a...
# 3   How do I add new information if I have already...
# 4   Does the reputation/history of my undergraduat...
# 5   When I print the application in PDF format par...
# 6   What is the desired length of work experience ...
# 7                    What constitutes work experience
# 8   Are there specific types of work experience th...
# 9                Who should recommendations come from
# 10               What is the process for recommenders
# 11  Is the recommendation deadline the same as the...
# 12  When should I expect an invitation for an inte...
# 13              What should I expect for my interview
# 14                             How can I best prepare
# 15  How can I learn more about the Post Interview ...
# 16  Who should I contact if I have a question rega...
# 17    When and how can I expect to hear back from HBS
# 18  Will HBS provide feedback for applicants who h...
# 19                 How long can I defer my acceptance
# 20                        What is the application fee
# 21          Am I eligible to apply to the 2+2 Program
# 22               What Round should I apply in for 2+2
# 23  I am in the process of getting a master’s degr...
# 24  Are international students eligible to apply t...
# 25  Is an interview required for admission to the ...
# 26    How many seats are available in the 2+2 program
# 27  Which standardized tests does the 2+2 Program ...
# 28      When is the latest I can take the GMAT or GRE
# 29  My undergraduate concentration is in a busines...
# ..                                                ...
# 45  What is the range of GMAT/GRE scores for accep...
# 46          Can I list only my best GMAT or GRE score
# 47  Do I need to complete the AWA section of the G...
# 48  Do I need to complete the Integrated Reasoning...
# 49   Who is required to take an English Language test
# 50  What if I have lived and worked in an English ...
# 51  What if part of my bachelor's degree was part ...
# 52  What if my undergraduate degree was not in Eng...
# 53  What is the latest date English test scores wi...
# 54                         What is the HBS TOEFL code
# 55  Is there a minimum TOEFL/IELTS/PTE test score ...
# 56                     How can I submit my transcript
# 57        Is there a minimum GPA requirement to apply
# 58       What is the average GPA of accepted students
# 59  Do you accept transfer credits from another co...
# 60  Financial Aid: What is the estimated cost for ...
# 61  Financial Aid: What are some options for finan...
# 62  Case Method: What makes the HBS case method su...
# 63         Sections: How is the curriculum structured
# 64  Academic Environment: Is it possible to cross ...
# 65    Program Offerings: Does HBS offer an online MBA
# 66  Program Offerings: Does HBS offer a part-time ...
# 67  What are the extracurricular activities available
# 68        What percentage of students lives on campus
# 69                 What are my transportation options
# 70  What social opportunities do Harvard Square an...
# 71                How can I sign up for a campus tour
# 72  How can I sign up for a classroom visit and is...
# 73         What events are held for accepted students
# 74  As a student, will I have the opportunity to n...
#
#                                                Answer  \
# 0                         View application deadlines.
# 1   Each application received is reviewed in depth...
# 2   Please enter important information that you wa...
# 3   Once the application has been submitted the Ad...
# 4   Our goal is to admit a class that offers a var...
# 5   The Admissions Office receives the entire appl...
# 6   The HBS MBA Program is designed for students w...
# 7   Work experience includes opportunities in whic...
# 8   Rather than focus on specific categories of wo...
# 9   The Admissions Board suggests that one recomme...
# 10  Candidates enter recommenders' names and email...
# 11  Applicants should submit their applications as...
# 12  Interview invitations are extended on a rollin...
# 13  Your interview will last approximately 30 minu...
# 14  The purpose of the interview is to better unde...
# 15  Details for the Post Interview Reflection will...
# 16  Any questions you have should be submitted to ...
# 17  Notification dates are set according to each r...
# 18  Due to the large number of applications we rec...
# 19  Candidates should submit applications only for...
# 20  The application fee for the 2+2 Program applic...
# 21  To be considered for admission to the 2+2 Prog...
# 22    You can only apply in the designated 2+2 Round.
# 23  Yes. Candidates in the process of completing a...
# 24  Yes. Domestic and international students alike...
# 25  Yes. Interviews are conducted by invitation on...
# 26  We expect the 2+2 cohort size to be in the 100...
# 27  The 2+2 Program accepts either the GMAT or the...
# 28  You must take the GMAT or GRE by April 10, 201...
# 29  When the 2+2 Program was originally created it...
# ..                                                ...
# 45  The Admissions Board hopes that all applicants...
# 46  Yes.  We consider only the score from a single...
# 47  Yes. You do not need to have the results of th...
# 48  Yes. Anyone who takes the GMAT on or after Jun...
# 49  If you only have a degree (or degrees) from a ...
# 50  Again, if you only have a degree (or degrees) ...
# 51  In this case, you are still required to take a...
# 52  Though it is not required as part of your init...
# 53  TOEFL, IELTS, and Pearson Test of English (PTE...
# 54  Please note that the HBS code for the TOEFL is...
# 55  HBS does not have a minimum test score to appl...
# 56  Transcripts must be scanned and uploaded to th...
# 57  No. Although our students often have competiti...
# 58  Because we recognize that different schools us...
# 59  No, we do no accept transfer credits of any ki...
# 60  While living expenses vary from student to stu...
# 61  HBS is committed to making the MBA Program acc...
# 62  The case method prepares students for the chal...
# 63  Students spend their first two terms completin...
# 64  Yes. HBS students are able to cross register a...
# 65  Harvard Business School does not offer an onli...
# 66  HBS has one MBA program, and it is offered onl...
# 67  Harvard Business School is home to over 70 ind...
# 68  Over 80% of HBS students live in HBS dorms or ...
# 69  The HBS campus is accessible via either car or...
# 70  Harvard Square and the neighboring Cambridge a...
# 71  There is no need to sign up for a campus tour....
# 72  To schedule a class visit please refer to the ...
# 73  We hold Admitted Student Welcome events on cam...
# 74  Absolutely. HBS has many networking events and...
#
#                                          Class
# 0                          Application General
# 1                          Application General
# 2                          Application General
# 3                          Application General
# 4                          Application General
# 5                          Application General
# 6                              Work Experience
# 7                              Work Experience
# 8                              Work Experience
# 9                              Recommendations
# 10                             Recommendations
# 11                             Recommendations
# 12                                   Interview
# 13                                   Interview
# 14                                   Interview
# 15                   Post Interview Reflection
# 16                       Application Follow-up
# 17                       Application Follow-up
# 18                       Application Follow-up
# 19                       Application Follow-up
# 20                                 2+2 Program
# 21                                 2+2 Program
# 22                                 2+2 Program
# 23                                 2+2 Program
# 24                                 2+2 Program
# 25                                 2+2 Program
# 26                                 2+2 Program
# 27                                 2+2 Program
# 28                                 2+2 Program
# 29                                 2+2 Program
# ..                                         ...
# 45                          GMAT and GRE Tests
# 46                          GMAT and GRE Tests
# 47                          GMAT and GRE Tests
# 48                          GMAT and GRE Tests
# 49  English Language Tests (TOEFL, IELTS, PTE)
# 50  English Language Tests (TOEFL, IELTS, PTE)
# 51  English Language Tests (TOEFL, IELTS, PTE)
# 52  English Language Tests (TOEFL, IELTS, PTE)
# 53  English Language Tests (TOEFL, IELTS, PTE)
# 54  English Language Tests (TOEFL, IELTS, PTE)
# 55  English Language Tests (TOEFL, IELTS, PTE)
# 56                                 Transcripts
# 57                                 Transcripts
# 58                                 Transcripts
# 59                                 Transcripts
# 60                          Financing your MBA
# 61                          Financing your MBA
# 62                          HBS Learning Model
# 63                          HBS Learning Model
# 64                          HBS Learning Model
# 65                          HBS Learning Model
# 66                          HBS Learning Model
# 67                                Student Life
# 68                                Student Life
# 69                                Student Life
# 70                                Student Life
# 71         Events and Networking Opportunities
# 72         Events and Networking Opportunities
# 73         Events and Networking Opportunities
# 74         Events and Networking Opportunities
#
# [75 rows x 3 columns]

# %%
from pandas import ExcelWriter

writer = ExcelWriter('QA.xls')
data.to_excel(writer,'Sheet5')
writer.save()

# %%
stemmer = LancasterStemmer()
def cleanup(sentence):
    word_tok = nltk.word_tokenize(sentence)
    stemmed_words = [stemmer.stem(w) for w in word_tok]

    return ' '.join(stemmed_words)


le = LE()

tfv = TfidfVectorizer(min_df=1, stop_words='english')

#data = pd.read_csv('qa.csv')
questions = data['Question'].values

X = []
for question in questions:
    X.append(cleanup(question))

tfv.fit(X)
le.fit(data['Class'])

X = tfv.transform(X)
y = le.transform(data['Class'])


trainx, testx, trainy, testy = tts(X, y, test_size=.25, random_state=42)

model = SVC(kernel='linear')
model.fit(trainx, trainy)
#print("SVC:", model.score(testx, testy))

# %%
def get_max5(arr):
    ixarr = []
    for ix, el in enumerate(arr):
        ixarr.append((el, ix))
    ixarr.sort()

    ixs = []
    for i in ixarr[-5:]:
        ixs.append(i[1])

    return ixs[::-1]

# %%
def chat():
    cnt = 0
    print("PRESS Q to QUIT")
    print("TYPE \"DEBUG\" to Display Debugging statements.")
    print("TYPE \"STOP\" to Stop Debugging statements.")
    print("TYPE \"TOP5\" to Display 5 most relevent results")
    print("TYPE \"CONF\" to Display the most confident result")
    print()
    print()
    DEBUG = False
    TOP5 = False

    print("Bot: Hi, Welcome to our Institute!")
    while True:
        usr = input("You: ")

        if usr.lower() == 'yes':
            print("Bot: Yes!")
            continue

        if usr.lower() == 'no':
            print("Bot: No?")
            continue

        if usr == 'DEBUG':
            DEBUG = True
            print("Debugging mode on")
            continue

        if usr == 'STOP':
            DEBUG = False
            print("Debugging mode off")
            continue

        if usr == 'Q':
            print("Bot: It was good to be of help.")
            break

        if usr == 'TOP5':
            TOP5 = True
            print("Will display 5 most relevent results now")
            continue

        if usr == 'CONF':
            TOP5 = False
            print("Only the most relevent result will be displayed")
            continue

        t_usr = tfv.transform([cleanup(usr.strip().lower())])
        class_ = le.inverse_transform(model.predict(t_usr)[0])
        questionset = data[data['Class']==class_]

        if DEBUG:
            print("Question classified under category:", class_)
            print("{} Questions belong to this class".format(len(questionset)))

        cos_sims = []
        for question in questionset['Question']:
            sims = cosine_similarity(tfv.transform([question]), t_usr)
            cos_sims.append(sims)
            
        ind = cos_sims.index(max(cos_sims))

        if DEBUG:
            question = questionset["Question"][questionset.index[ind]]
            print("Assuming you asked: {}".format(question))

        if not TOP5:
            print("Bot:", data['Answer'][questionset.index[ind]])
        else:
            inds = get_max5(cos_sims)
            for ix in inds:
                print("Question: "+data['Question'][questionset.index[ix]])
                print("Answer: "+data['Answer'][questionset.index[ix]])
                print('-'*50)

        print("\n"*2)
        outcome = input("Was this answer helpful? Yes/No: ").lower().strip()
        if outcome == 'yes':
            cnt = 0
        elif outcome == 'no':
            inds = get_max5(cos_sims)
            sugg_choice = input("Bot: Do you want me to suggest you questions ? Yes/No: ").lower()
            if sugg_choice == 'yes':
                q_cnt = 1
                for ix in inds:
                    print(q_cnt,"Question: "+data['Question'][questionset.index[ix]])
                    # print("Answer: "+data['Answer'][questionset.index[ix]])
                    print('-'*50)
                    q_cnt += 1
                num = int(input("Please enter the question number you find most relevant: "))
                print("Bot: ", data['Answer'][questionset.index[inds[num-1]]])


chat()
# Out:
# PRESS Q to QUIT
# TYPE "DEBUG" to Display Debugging statements.
# TYPE "STOP" to Stop Debugging statements.
# TYPE "TOP5" to Display 5 most relevent results
# TYPE "CONF" to Display the most confident result
#
#
# Bot: Hi, Welcome to our Institute!
# You: How can I sign up for a campus tour?
# C:\Users\Suhas\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Bot: There is no need to sign up for a campus tour. You can find the tour schedule on our visit page.
#
#
#
# Was this answer helpful? Yes/No: what events are held?
# You: yes
# Bot: Yes!
# You: what events are held?
# C:\Users\Suhas\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Bot: We hold Admitted Student Welcome events on campus in February and April. We also will host regional events in many cities throughout the world.
#
#
#
# Was this answer helpful? Yes/No: No
# Bot: Do you want me to suggest you questions ? Yes/No: Yes
# 1 Question: What events are held for accepted students
# --------------------------------------------------
# 2 Question: As a student, will I have the opportunity to network with alumni through organized events
# --------------------------------------------------
# 3 Question: How can I sign up for a classroom visit and is there a limit to how many I can attend
# --------------------------------------------------
# 4 Question: How can I sign up for a campus tour
# --------------------------------------------------
# Please enter the question number you find most relevant: 4
# Bot:  There is no need to sign up for a campus tour. You can find the tour schedule on our visit page.
# You: until when I can apply?
# C:\Users\Suhas\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Bot: To be considered for admission to the 2+2 Program Class of 2022 (entering fall 2020), you must graduate from your program between October 1, 2017 and September 30, 2018. For more information on applying to the 2+2 Program, please see the 2+2 Application page.
